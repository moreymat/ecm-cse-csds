# %% [markdown]
# # Loading big datasets
#
# In this series of notebooks, we will analyze the nutritional profile of food products using an open database : OpenFoodFacts.

# %% [markdown]
# ## OpenFoodFacts
# [OpenFoodFacts](https://fr-en.openfoodfacts.org/) is an open database on food products.
# It is built as a common, where anyone can contribute data on packaged food products : pictures, ingredients, nutritional values, etc.
# This database serves as the basis for many apps for mobile phones, in particular scan apps to help customers when they buy groceries.
#
# The database and various exports can be downloaded from [this page](https://fr-en.openfoodfacts.org/data).
#
# We will work on the CSV export of the database.
# It contains data on more than 1.4 million products and weighs 3 GB (as of 2020-09-26).

# %% [markdown]
# You need to :
# - Download the data from [this link](https://static.openfoodfacts.org/data/fr.openfoodfacts.org.products.csv).
# - Open the documentation of the CSV export, with useful information about the fields, in this [text file](https://static.openfoodfacts.org/data/data-fields.txt).

# %%
# change to the (absolute or relative) path to the CSV file on your computer
CSV_FILE = '/home/mathieu/datasets/openfoodfacts/2020-09-26/fr.openfoodfacts.org.products.csv'

# %% [markdown]
# ## Testing the waters : Requirements before loading

# %% [markdown]
# If we naively call `read_csv` with its default parameters on a file as big as the CSV export from OpenFoodFacts, there is a chance that things don't go well and pandas completely fills the computer memory before crashing.
# This is due to the fact that [the CSV file format is not a fully standardized format](https://en.wikipedia.org/wiki/Comma-separated_values).
# Rather, CSV is currently used as an umbrella term for a family of formats for flat, tabular data.
#
# The documentation of [read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) and its list of parameters give a broad overview of the main variants of the format, such as which character is used as the field separator (or delimiter), whether column names are written as a header of one or more lines, how to handle and interpret blank lines, how to handle and interpret quoted items, etc.
# `read_csv` tries to be smart and infer some of these properties but does not always succeed, so you need to guide it and provide it with the right parameters for your file.
#
# You can usually find out more about the format of your dataset by reading the accompanying documentation.
# Utilities such as [csvkit](https://csvkit.readthedocs.io/en/latest/) can help you figuring out the rest.
# Last, a simple pager program such as [less](https://en.wikipedia.org/wiki/Less_(Unix)) is very helpful when you deal with very large files.

# %% [markdown]
# For the CSV export of OpenFoodFacts :
# - The field separator in this file is a `<tab>`, as stated in the documentation (text file linked above) ;
# - The first line contains the column names, as can be seen when opening the file with `less`.
#
# Hence we will need to provide `read_csv` with parameters :
# - `sep='\t'`,
# - `header=0` (the first line has index 0, because python counts from 0).

# %% [markdown]
# ## Dipping our toes : Loading slices of the dataset

# %%
import pandas as pd

# %% [markdown]
# We start by reading only the first 1000 rows (`nrows=1000`) to have a first look at the dataset and check its memory usage.
# Then we read the first 7000 rows, then the first 14000 rows, and monitor memory usage as a function of the number of rows.
# We will then perform a rough back-of-the-envelope calculation to extrapolate the memory requirements for loading the entire dataset (> 1.4 million entries), and evaluate the need for applying a few optimizations.

# %% [markdown]
# By default, [info()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html) returns a *shallow* computation of memory usage.
# Specifying `memory_usage='deep'` triggers a deeper introspection that returns a better estimate of the memory usage.

# %%
# read the first 1000 rows, display the first 5 rows
df = pd.read_csv(CSV_FILE, sep='\t', header=0, nrows=1000)
df.head(5)
# Out:
#          code                                                url  \
# 0          17  http://world-fr.openfoodfacts.org/produit/0000...
# 1          31  http://world-fr.openfoodfacts.org/produit/0000...
# 2     3327986  http://world-fr.openfoodfacts.org/produit/0000...
# 3         100  http://world-fr.openfoodfacts.org/produit/0000...
# 4  1111111111  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0                     kiliweb  1529059080  2018-06-15T10:38:00Z
# 1                    isagoofy  1539464774  2018-10-13T21:06:14Z
# 2                     kiliweb  1574175736  2019-11-19T15:02:16Z
# 3                       del51  1444572561  2015-10-11T14:09:21Z
# 4  openfoodfacts-contributors  1560020173  2019-06-08T18:56:13Z
#
#    last_modified_t last_modified_datetime                  product_name  \
# 0       1561463718   2019-06-25T11:55:18Z              Vitória crackers
# 1       1539464817   2018-10-13T21:06:57Z                         Cacao
# 2       1574175737   2019-11-19T15:02:17Z     Filetes de pollo empanado
# 3       1444659212   2015-10-12T14:13:32Z   moutarde au moût de raisin
# 4       1560020173   2019-06-08T18:56:13Z                       Sfiudwx
#
#   generic_name quantity  ... carbon-footprint-from-meat-or-fish_100g  \
# 0          NaN      NaN  ...                                     NaN
# 1          NaN    130 g  ...                                     NaN
# 2          NaN      NaN  ...                                     NaN
# 3          NaN     100g  ...                                     NaN
# 4          NaN    dgesc  ...                                     NaN
#
#   nutrition-score-fr_100g nutrition-score-uk_100g glycemic-index_100g  \
# 0                     NaN                     NaN                 NaN
# 1                     NaN                     NaN                 NaN
# 2                     NaN                     NaN                 NaN
# 3                    18.0                     NaN                 NaN
# 4                     NaN                     NaN                 NaN
#
#   water-hardness_100g choline_100g phylloquinone_100g beta-glucan_100g  \
# 0                 NaN          NaN                NaN              NaN
# 1                 NaN          NaN                NaN              NaN
# 2                 NaN          NaN                NaN              NaN
# 3                 NaN          NaN                NaN              NaN
# 4                 NaN          NaN                NaN              NaN
#
#   inositol_100g carnitine_100g
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
#
# [5 rows x 181 columns]

# %% [markdown]
# Check the memory usage of the DataFrame containing these 1000 rows.

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Columns: 181 entries, code to carnitine_100g
# dtypes: float64(123), int64(3), object(55)
# memory usage: 4.8 MB

# %% [markdown]
# Load the first 7000 rows and check their memory usage.

# %%
# load 7000 rows and check memory usage

# %% [markdown]
# Load the first 14000 rows and check their memory usage.

# %%
# load 14000 rows and check memory usage

# %% [markdown]
# Can you observe a trend in the memory usage ?
# How much memory would be necessary to load 1.4 million entries ?

# %% [markdown]
# ## Helper 1 : Loading only the columns of interest
# [read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) has a parameter `usecols` where you can specify which columns you want to load.
# The values for the other columns are discarded immediately after they are read, which directly reduces memory usage.
# This seems like a good, safe, first strategy to cut memory usage.
#
# It is often easier to determine the columns that we *do not want to keep*.
# They fall under two categories :
# - Columns that are not directly useful for our primary purpose of analyzing nutritional values, such as those containing metadata for the database entry ("creator", "last_modified_t", etc.), manufacturing places, place of purchase, etc ;
# - Columns that are completely, or almost completely empty, and will not be able to contribute to the analysis.
#
# It is likely that many columns in OpenFoodFacts will belong to the second category, because the database schema contains many columns for data that is not mandatory on food packaging, or data that is harder to collect.

# %% [markdown]
# In order to check the emptiness of columns, we will once again make use of `info`.
# Because there are many columns, `info` only displays a minimal summary by default, so we need to explicitly ask for the full list of column names, types and non-null counts with the parameters `verbose=True, null_counts=True`.

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 181 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   code                                        14000 non-null  object
#  1   url                                         14000 non-null  object
#  2   creator                                     14000 non-null  object
#  3   created_t                                   14000 non-null  int64
#  4   created_datetime                            14000 non-null  object
#  5   last_modified_t                             14000 non-null  int64
#  6   last_modified_datetime                      14000 non-null  object
#  7   product_name                                13641 non-null  object
#  8   generic_name                                195 non-null    object
#  9   quantity                                    875 non-null    object
#  10  packaging                                   426 non-null    object
#  11  packaging_tags                              426 non-null    object
#  12  brands                                      9562 non-null   object
#  13  brands_tags                                 9562 non-null   object
#  14  categories                                  10649 non-null  object
#  15  categories_tags                             10649 non-null  object
#  16  categories_fr                               10649 non-null  object
#  17  origins                                     89 non-null     object
#  18  origins_tags                                88 non-null     object
#  19  manufacturing_places                        162 non-null    object
#  20  manufacturing_places_tags                   162 non-null    object
#  21  labels                                      942 non-null    object
#  22  labels_tags                                 942 non-null    object
#  23  labels_fr                                   942 non-null    object
#  24  emb_codes                                   68 non-null     object
#  25  emb_codes_tags                              68 non-null     object
#  26  first_packaging_code_geo                    32 non-null     object
#  27  cities                                      0 non-null      float64
#  28  cities_tags                                 33 non-null     object
#  29  purchase_places                             255 non-null    object
#  30  stores                                      2408 non-null   object
#  31  countries                                   13964 non-null  object
#  32  countries_tags                              13964 non-null  object
#  33  countries_fr                                13964 non-null  object
#  34  ingredients_text                            11752 non-null  object
#  35  allergens                                   1743 non-null   object
#  36  allergens_fr                                0 non-null      float64
#  37  traces                                      149 non-null    object
#  38  traces_tags                                 203 non-null    object
#  39  traces_fr                                   203 non-null    object
#  40  serving_size                                11446 non-null  object
#  41  serving_quantity                            11446 non-null  float64
#  42  no_nutriments                               0 non-null      float64
#  43  additives_n                                 11752 non-null  float64
#  44  additives                                   0 non-null      float64
#  45  additives_tags                              7778 non-null   object
#  46  additives_fr                                7778 non-null   object
#  47  ingredients_from_palm_oil_n                 11752 non-null  float64
#  48  ingredients_from_palm_oil                   0 non-null      float64
#  49  ingredients_from_palm_oil_tags              32 non-null     object
#  50  ingredients_that_may_be_from_palm_oil_n     11752 non-null  float64
#  51  ingredients_that_may_be_from_palm_oil       0 non-null      float64
#  52  ingredients_that_may_be_from_palm_oil_tags  898 non-null    object
#  53  nutriscore_score                            8301 non-null   float64
#  54  nutriscore_grade                            8301 non-null   object
#  55  nova_group                                  10825 non-null  float64
#  56  pnns_groups_1                               13980 non-null  object
#  57  pnns_groups_2                               13996 non-null  object
#  58  states                                      14000 non-null  object
#  59  states_tags                                 14000 non-null  object
#  60  states_fr                                   14000 non-null  object
#  61  brand_owner                                 9758 non-null   object
#  62  main_category                               10649 non-null  object
#  63  main_category_fr                            10649 non-null  object
#  64  image_url                                   2744 non-null   object
#  65  image_small_url                             2744 non-null   object
#  66  image_ingredients_url                       1686 non-null   object
#  67  image_ingredients_small_url                 1686 non-null   object
#  68  image_nutrition_url                         1421 non-null   object
#  69  image_nutrition_small_url                   1421 non-null   object
#  70  energy-kj_100g                              77 non-null     float64
#  71  energy-kcal_100g                            12844 non-null  float64
#  72  energy_100g                                 12906 non-null  float64
#  73  energy-from-fat_100g                        26 non-null     float64
#  74  fat_100g                                    12846 non-null  float64
#  75  saturated-fat_100g                          11012 non-null  float64
#  76  butyric-acid_100g                           0 non-null      float64
#  77  caproic-acid_100g                           0 non-null      float64
#  78  caprylic-acid_100g                          0 non-null      float64
#  79  capric-acid_100g                            0 non-null      float64
#  80  lauric-acid_100g                            0 non-null      float64
#  81  myristic-acid_100g                          0 non-null      float64
#  82  palmitic-acid_100g                          0 non-null      float64
#  83  stearic-acid_100g                           0 non-null      float64
#  84  arachidic-acid_100g                         0 non-null      float64
#  85  behenic-acid_100g                           0 non-null      float64
#  86  lignoceric-acid_100g                        0 non-null      float64
#  87  cerotic-acid_100g                           0 non-null      float64
#  88  montanic-acid_100g                          0 non-null      float64
#  89  melissic-acid_100g                          0 non-null      float64
#  90  monounsaturated-fat_100g                    1846 non-null   float64
#  91  polyunsaturated-fat_100g                    1847 non-null   float64
#  92  omega-3-fat_100g                            0 non-null      float64
#  93  alpha-linolenic-acid_100g                   0 non-null      float64
#  94  eicosapentaenoic-acid_100g                  0 non-null      float64
#  95  docosahexaenoic-acid_100g                   0 non-null      float64
#  96  omega-6-fat_100g                            0 non-null      float64
#  97  linoleic-acid_100g                          0 non-null      float64
#  98  arachidonic-acid_100g                       0 non-null      float64
#  99  gamma-linolenic-acid_100g                   0 non-null      float64
#  100 dihomo-gamma-linolenic-acid_100g            0 non-null      float64
#  101 omega-9-fat_100g                            0 non-null      float64
#  102 oleic-acid_100g                             0 non-null      float64
#  103 elaidic-acid_100g                           0 non-null      float64
#  104 gondoic-acid_100g                           0 non-null      float64
#  105 mead-acid_100g                              0 non-null      float64
#  106 erucic-acid_100g                            0 non-null      float64
#  107 nervonic-acid_100g                          0 non-null      float64
#  108 trans-fat_100g                              8914 non-null   float64
#  109 cholesterol_100g                            9053 non-null   float64
#  110 carbohydrates_100g                          12862 non-null  float64
#  111 sugars_100g                                 12033 non-null  float64
#  112 sucrose_100g                                0 non-null      float64
#  113 glucose_100g                                0 non-null      float64
#  114 fructose_100g                               0 non-null      float64
#  115 lactose_100g                                0 non-null      float64
#  116 maltose_100g                                0 non-null      float64
#  117 maltodextrins_100g                          0 non-null      float64
#  118 starch_100g                                 3 non-null      float64
#  119 polyols_100g                                56 non-null     float64
#  120 fiber_100g                                  9338 non-null   float64
#  121 soluble-fiber_100g                          66 non-null     float64
#  122 insoluble-fiber_100g                        31 non-null     float64
#  123 proteins_100g                               12844 non-null  float64
#  124 casein_100g                                 0 non-null      float64
#  125 serum-proteins_100g                         0 non-null      float64
#  126 nucleotides_100g                            0 non-null      float64
#  127 salt_100g                                   12714 non-null  float64
#  128 sodium_100g                                 12714 non-null  float64
#  129 alcohol_100g                                47 non-null     float64
#  130 vitamin-a_100g                              7963 non-null   float64
#  131 beta-carotene_100g                          0 non-null      float64
#  132 vitamin-d_100g                              404 non-null    float64
#  133 vitamin-e_100g                              1 non-null      float64
#  134 vitamin-k_100g                              18 non-null     float64
#  135 vitamin-c_100g                              8114 non-null   float64
#  136 vitamin-b1_100g                             730 non-null    float64
#  137 vitamin-b2_100g                             737 non-null    float64
#  138 vitamin-pp_100g                             771 non-null    float64
#  139 vitamin-b6_100g                             381 non-null    float64
#  140 vitamin-b9_100g                             277 non-null    float64
#  141 folates_100g                                366 non-null    float64
#  142 vitamin-b12_100g                            288 non-null    float64
#  143 biotin_100g                                 6 non-null      float64
#  144 pantothenic-acid_100g                       155 non-null    float64
#  145 silica_100g                                 0 non-null      float64
#  146 bicarbonate_100g                            0 non-null      float64
#  147 potassium_100g                              2159 non-null   float64
#  148 chloride_100g                               0 non-null      float64
#  149 calcium_100g                                8845 non-null   float64
#  150 phosphorus_100g                             369 non-null    float64
#  151 iron_100g                                   8853 non-null   float64
#  152 magnesium_100g                              288 non-null    float64
#  153 zinc_100g                                   277 non-null    float64
#  154 copper_100g                                 121 non-null    float64
#  155 manganese_100g                              110 non-null    float64
#  156 fluoride_100g                               0 non-null      float64
#  157 selenium_100g                               69 non-null     float64
#  158 chromium_100g                               6 non-null      float64
#  159 molybdenum_100g                             6 non-null      float64
#  160 iodine_100g                                 60 non-null     float64
#  161 caffeine_100g                               0 non-null      float64
#  162 taurine_100g                                0 non-null      float64
#  163 ph_100g                                     0 non-null      float64
#  164 fruits-vegetables-nuts_100g                 3 non-null      float64
#  165 fruits-vegetables-nuts-dried_100g           0 non-null      float64
#  166 fruits-vegetables-nuts-estimate_100g        20 non-null     float64
#  167 collagen-meat-protein-ratio_100g            0 non-null      float64
#  168 cocoa_100g                                  10 non-null     float64
#  169 chlorophyl_100g                             0 non-null      float64
#  170 carbon-footprint_100g                       0 non-null      float64
#  171 carbon-footprint-from-meat-or-fish_100g     20 non-null     float64
#  172 nutrition-score-fr_100g                     8301 non-null   float64
#  173 nutrition-score-uk_100g                     0 non-null      float64
#  174 glycemic-index_100g                         0 non-null      float64
#  175 water-hardness_100g                         0 non-null      float64
#  176 choline_100g                                0 non-null      float64
#  177 phylloquinone_100g                          65 non-null     float64
#  178 beta-glucan_100g                            0 non-null      float64
#  179 inositol_100g                               0 non-null      float64
#  180 carnitine_100g                              0 non-null      float64
# dtypes: float64(123), int64(2), object(56)
# memory usage: 19.3+ MB

# %% [markdown]
# As you can see :
# - Some fields are always set,
# - A number of fields are often set,
# - Many columns are never set.

# %% [markdown]
# Optional exercise : plot the distribution of column non-null counts.

# %% [markdown]
# Once we exclude the metadata and (mostly) empty columns, we are left with the set of columns that will be useful for our analysis.
# Here we just filter the columns in the current dataset, but in the next notebook we will provide `read_csv` with this list of columns.

# %%
keep_cols = ["code", "url", "product_name", "brands", "categories",
             "countries_tags",
             "additives_tags",
             "nutriscore_score", "nutriscore_grade",
             "nova_group",
             "pnns_groups_1", "pnns_groups_2",
             "states",
             "energy-kcal_100g",
             "fat_100g", "saturated-fat_100g", "trans-fat_100g", "cholesterol_100g",
             "carbohydrates_100g", "sugars_100g",
             "fiber_100g",
             "proteins_100g",
             "salt_100g", "sodium_100g",
             "vitamin-a_100g",
             "vitamin-c_100g",
             "calcium_100g",
             "iron_100g",
             "nutrition-score-fr_100g"
]
# check that our list of columns is correct and the selection works
df = df[keep_cols]
df

# %% [markdown]
# This filtering on columns can be done during reading for greater efficiency.

# %%
df = pd.read_csv(CSV_FILE, sep='\t', header=0, usecols=keep_cols, nrows=14000)

# %% [markdown]
# Loading only 29 columns instead of the original 181 columns should have saved a lot of memory.
#
# Check the (deep) memory usage of this smaller DataFrame.

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   code                     14000 non-null  object
#  1   url                      14000 non-null  object
#  2   product_name             13641 non-null  object
#  3   brands                   9562 non-null   object
#  4   categories               10649 non-null  object
#  5   countries_tags           13964 non-null  object
#  6   additives_tags           7778 non-null   object
#  7   nutriscore_score         8301 non-null   float64
#  8   nutriscore_grade         8301 non-null   object
#  9   nova_group               10825 non-null  float64
#  10  pnns_groups_1            13980 non-null  object
#  11  pnns_groups_2            13996 non-null  object
#  12  states                   14000 non-null  object
#  13  energy-kcal_100g         12844 non-null  float64
#  14  fat_100g                 12846 non-null  float64
#  15  saturated-fat_100g       11012 non-null  float64
#  16  trans-fat_100g           8914 non-null   float64
#  17  cholesterol_100g         9053 non-null   float64
#  18  carbohydrates_100g       12862 non-null  float64
#  19  sugars_100g              12033 non-null  float64
#  20  fiber_100g               9338 non-null   float64
#  21  proteins_100g            12844 non-null  float64
#  22  salt_100g                12714 non-null  float64
#  23  sodium_100g              12714 non-null  float64
#  24  vitamin-a_100g           7963 non-null   float64
#  25  vitamin-c_100g           8114 non-null   float64
#  26  calcium_100g             8845 non-null   float64
#  27  iron_100g                8853 non-null   float64
#  28  nutrition-score-fr_100g  8301 non-null   float64
# dtypes: float64(18), object(11)
# memory usage: 17.4 MB

# %% [markdown]
# Using the same ratio as earlier, how much memory would be needed to load the full dataset restricted to these 29 columns ?

# %% [markdown]
# ## Helper 2 : Explicitly modelling categorical variables
# Some columns in the OpenFoodFacts dataset correspond to categorical variables, for example the [NOVA groups](https://world.openfoodfacts.org/nova) (`nova_group`) and [Nutri-Score grade](https://en.wikipedia.org/wiki/Nutri-score) (`nutriscore_grade`).
# Categorical variables typically have a small number of possible values, much lower than the number of occurrences in a big dataset.
#
# pandas has a specific data type named [categorical](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html) with 2 main advantages here :
# - memory efficiency : all instances of a given value point to a unique shared representation, [saving memory](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html?highlight=categorical#memory-usage),
# - interoperability : categorical variables have specific support in libraries for statistical analysis, machine learning, or visualization (plots).

# %%
from pandas.api.types import CategoricalDtype

# %% [markdown]
# We can search for candidate categorical variables by looking at their name and the number of unique values in each column of the dataset.

# %% [markdown]
# Display the number of unique value in each column of the DataFrame with [nunique()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.nunique.html).

# %%
# TODO

# %% [markdown]
# Four columns have a very low number of distinct values, and a name that could correspond to categorical variables :
# - `nutriscore_grade`,
# - `nova_group`,
# - `pnns_groups_1`,
# - `pnns_groups_2`.
#
# We can check if this is the case by looking at the list of their unique values.

# %% [markdown]
# List the unique values for `nutriscore_grade` using [unique()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.unique.html).

# %%
# TODO

# %% [markdown]
# The 6 values of `nutriscore_grade` correspond to the 5 values of the [Nutri-Score](https://en.wikipedia.org/wiki/Nutri-score), plus `nan` for missing values.
# This is indeed a categorical variable.

# %% [markdown]
# List the unique values for `nova_group`.

# %%
# TODO

# %% [markdown]
# List the unique values for `pnns_groups_1`.

# %%
# TODO

# %% [markdown]
# List the unique values for `pnns_groups_2`.

# %%
# TODO

# %% [markdown]
# Categorical variables can be :
# - unordered, like `pnns_groups_1` and `pnns_groups_2`,
# - ordered, like `nova_group` (from '1' for unprocessed foods to '4' for ultra-processed foods) and `nutriscore_grade` (from 'a' for the healthiest foods to 'e' for the least healthy foods).

# %% [markdown]
# Declare those categorical variables in a mapping that can serve as the argument `dtype` of `read_csv`.

# %%
dtype = {
    # 'code' should be read as a string
    'code': str,
    # ordered categoricals, with explicit list of values
    'nova_group': CategoricalDtype(categories=['1', '2', '3', '4'], ordered=True),
    'nutriscore_grade': CategoricalDtype(categories=['a', 'b', 'c', 'd', 'e'], ordered=True),
    # unordered categoricals, values will be inferred during reading
    'pnns_groups_1': 'category',
    'pnns_groups_2': 'category'
}

# %% [markdown]
# Re-load the first 14000 entries of the dataset, restricted to `keep_cols`, with explicit data types for categorical variables.

# %%
df = pd.read_csv(CSV_FILE, sep='\t', header=0, usecols=keep_cols, dtype=dtype, nrows=14000)
df
# Out:
#                        code  \
# 0             0000000000017
# 1             0000000000031
# 2        000000000003327986
# 3             0000000000100
# 4      00000000001111111111
# ...                     ...
# 13995         0011213902654
# 13996         0011213902685
# 13997         0011213902692
# 13998         0011213902722
# 13999         0011213902739
#
#                                                      url  \
# 0      http://world-fr.openfoodfacts.org/produit/0000...
# 1      http://world-fr.openfoodfacts.org/produit/0000...
# 2      http://world-fr.openfoodfacts.org/produit/0000...
# 3      http://world-fr.openfoodfacts.org/produit/0000...
# 4      http://world-fr.openfoodfacts.org/produit/0000...
# ...                                                  ...
# 13995  http://world-fr.openfoodfacts.org/produit/0011...
# 13996  http://world-fr.openfoodfacts.org/produit/0011...
# 13997  http://world-fr.openfoodfacts.org/produit/0011...
# 13998  http://world-fr.openfoodfacts.org/produit/0011...
# 13999  http://world-fr.openfoodfacts.org/produit/0011...
#
#                                             product_name         brands  \
# 0                                       Vitória crackers            NaN
# 1                                                  Cacao            NaN
# 2                              Filetes de pollo empanado            NaN
# 3                            moutarde au moût de raisin   courte paille
# 4                                                Sfiudwx           Watt
# ...                                                  ...            ...
# 13995                              Deli Style Roast Beef        Spartan
# 13996  Spartan, original diced tomato with green chilies        Spartan
# 13997                               Spartan, diced pears        Spartan
# 13998             Spartan, hot cocoa mix, milk chocolate            NaN
# 13999      Spartan, hot cocoa mix with mini marshmallows            NaN
#
#                                               categories    countries_tags  \
# 0                                                    NaN         en:france
# 1                                                    NaN         en:france
# 2                                                    NaN          en:spain
# 3                Epicerie, Condiments, Sauces, Moutardes         en:france
# 4                                                    Xsf         en:france
# ...                                                  ...               ...
# 13995                              Meats, Prepared meats  en:united-states
# 13996  Plant-based foods and beverages, Plant-based f...  en:united-states
# 13997  Plant-based foods and beverages, Plant-based f...  en:united-states
# 13998  Beverages, Dried products, Dried products to b...  en:united-states
# 13999  Beverages, Dried products, Dried products to b...  en:united-states
#
#                                           additives_tags  nutriscore_score  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN              18.0
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 13995                 en:e150c,en:e262,en:e262ii,en:e326               4.0
# 13996                                            en:e330              -3.0
# 13997                                            en:e330              -3.0
# 13998          en:e100,en:e340,en:e340ii,en:e471,en:e551               NaN
# 13999  en:e100,en:e340,en:e340ii,en:e428,en:e471,en:e551               NaN
#
#       nutriscore_grade nova_group  ... sugars_100g fiber_100g proteins_100g  \
# 0                  NaN        NaN  ...       15.00        NaN          7.80
# 1                  NaN        NaN  ...         NaN        NaN           NaN
# 2                  NaN        NaN  ...         NaN        NaN           NaN
# 3                    d        NaN  ...       22.00        0.0          5.10
# 4                  NaN        NaN  ...         NaN        NaN           NaN
# ...                ...        ...  ...         ...        ...           ...
# 13995                c          4  ...        0.00        0.0         30.36
# 13996                a          4  ...        2.48        0.8          0.83
# 13997                a          3  ...       13.27        0.9          0.00
# 13998              NaN          4  ...       80.00        2.9          5.71
# 13999              NaN          4  ...       80.00        2.9          5.71
#
#        salt_100g  sodium_100g  vitamin-a_100g  vitamin-c_100g  calcium_100g  \
# 0         1.4000        0.560             NaN             NaN           NaN
# 1            NaN          NaN             NaN             NaN           NaN
# 2            NaN          NaN             NaN             NaN           NaN
# 3         4.6000        1.840             NaN             NaN           NaN
# 4            NaN          NaN             NaN             NaN           NaN
# ...          ...          ...             ...             ...           ...
# 13995     1.5625        0.625        0.000000          0.0000         0.000
# 13996     0.6200        0.248        0.000124          0.0050         0.033
# 13997     0.0225        0.009        0.000000          0.0531         0.000
# 13998     1.4275        0.571        0.000000          0.0000         0.171
# 13999     1.3575        0.543        0.000000          0.0000         0.171
#
#        iron_100g  nutrition-score-fr_100g
# 0            NaN                      NaN
# 1            NaN                      NaN
# 2            NaN                      NaN
# 3            NaN                     18.0
# 4            NaN                      NaN
# ...          ...                      ...
# 13995    0.00257                      4.0
# 13996    0.00060                     -3.0
# 13997    0.00000                     -3.0
# 13998    0.00206                      NaN
# 13999    0.00206                      NaN
#
# [14000 rows x 29 columns]

# %%
# check the DataFrame
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   code                     14000 non-null  object
#  1   url                      14000 non-null  object
#  2   product_name             13641 non-null  object
#  3   brands                   9562 non-null   object
#  4   categories               10649 non-null  object
#  5   countries_tags           13964 non-null  object
#  6   additives_tags           7778 non-null   object
#  7   nutriscore_score         8301 non-null   float64
#  8   nutriscore_grade         8301 non-null   category
#  9   nova_group               10825 non-null  category
#  10  pnns_groups_1            13980 non-null  category
#  11  pnns_groups_2            13996 non-null  category
#  12  states                   14000 non-null  object
#  13  energy-kcal_100g         12844 non-null  float64
#  14  fat_100g                 12846 non-null  float64
#  15  saturated-fat_100g       11012 non-null  float64
#  16  trans-fat_100g           8914 non-null   float64
#  17  cholesterol_100g         9053 non-null   float64
#  18  carbohydrates_100g       12862 non-null  float64
#  19  sugars_100g              12033 non-null  float64
#  20  fiber_100g               9338 non-null   float64
#  21  proteins_100g            12844 non-null  float64
#  22  salt_100g                12714 non-null  float64
#  23  sodium_100g              12714 non-null  float64
#  24  vitamin-a_100g           7963 non-null   float64
#  25  vitamin-c_100g           8114 non-null   float64
#  26  calcium_100g             8845 non-null   float64
#  27  iron_100g                8853 non-null   float64
#  28  nutrition-score-fr_100g  8301 non-null   float64
# dtypes: category(4), float64(17), object(8)
# memory usage: 15.2 MB

# %% [markdown]
# ## Helper 3 : Reducing the precision of floating-point numbers
#
# Another strategy that helps to reduce memory usage is to specify data types that suit the actual level of precision of the values.
# By default, pandas stores floating-point numbers as `float64`, ie. [Double-precision floating-point format](https://en.wikipedia.org/wiki/Double-precision_floating-point_format).
#
# On the OpenFoodfacts dataset, this conservative approach could be considered wasteful because nutritional values written on food packaging are not of an extreme precision.
# The minor loss of precision should not affect dramatically the analysis, so we could replace `float64` with [float16](https://en.wikipedia.org/wiki/Half-precision_floating-point_format) and cut memory usage for these columns by a factor of 4.

# %% [markdown]
# Cast the type of columns whose name ends with `_100g` as `float16` using [astype](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html).

# %%
num_cols = [x for x in list(df.columns) if x.endswith("_100g")]
dtype = {x: "float16" for x in num_cols}
df = df.astype(dtype)
df.head(5)
# Out:
#                    code                                                url  \
# 0         0000000000017  http://world-fr.openfoodfacts.org/produit/0000...
# 1         0000000000031  http://world-fr.openfoodfacts.org/produit/0000...
# 2    000000000003327986  http://world-fr.openfoodfacts.org/produit/0000...
# 3         0000000000100  http://world-fr.openfoodfacts.org/produit/0000...
# 4  00000000001111111111  http://world-fr.openfoodfacts.org/produit/0000...
#
#                    product_name         brands  \
# 0              Vitória crackers            NaN
# 1                         Cacao            NaN
# 2     Filetes de pollo empanado            NaN
# 3   moutarde au moût de raisin   courte paille
# 4                       Sfiudwx           Watt
#
#                                 categories countries_tags additives_tags  \
# 0                                      NaN      en:france            NaN
# 1                                      NaN      en:france            NaN
# 2                                      NaN       en:spain            NaN
# 3  Epicerie, Condiments, Sauces, Moutardes      en:france            NaN
# 4                                      Xsf      en:france            NaN
#
#    nutriscore_score nutriscore_grade  nova_group  ... sugars_100g fiber_100g  \
# 0               NaN              NaN         NaN  ...        15.0        NaN
# 1               NaN              NaN         NaN  ...         NaN        NaN
# 2               NaN              NaN         NaN  ...         NaN        NaN
# 3              18.0                d         NaN  ...        22.0        0.0
# 4               NaN              NaN         NaN  ...         NaN        NaN
#
#   proteins_100g  salt_100g  sodium_100g  vitamin-a_100g  vitamin-c_100g  \
# 0      7.800781   1.400391     0.560059             NaN             NaN
# 1           NaN        NaN          NaN             NaN             NaN
# 2           NaN        NaN          NaN             NaN             NaN
# 3      5.101562   4.601562     1.839844             NaN             NaN
# 4           NaN        NaN          NaN             NaN             NaN
#
#    calcium_100g  iron_100g  nutrition-score-fr_100g
# 0           NaN        NaN                      NaN
# 1           NaN        NaN                      NaN
# 2           NaN        NaN                      NaN
# 3           NaN        NaN                     18.0
# 4           NaN        NaN                      NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# Do you notice any change in the floating-point values ?

# %% [markdown]
# Check memory usage.

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   code                     14000 non-null  object
#  1   url                      14000 non-null  object
#  2   product_name             13641 non-null  object
#  3   brands                   9562 non-null   object
#  4   categories               10649 non-null  object
#  5   countries_tags           13964 non-null  object
#  6   additives_tags           7778 non-null   object
#  7   nutriscore_score         8301 non-null   float64
#  8   nutriscore_grade         8301 non-null   object
#  9   nova_group               10825 non-null  float64
#  10  pnns_groups_1            13980 non-null  object
#  11  pnns_groups_2            13996 non-null  object
#  12  states                   14000 non-null  object
#  13  energy-kcal_100g         12844 non-null  float16
#  14  fat_100g                 12846 non-null  float16
#  15  saturated-fat_100g       11012 non-null  float16
#  16  trans-fat_100g           8914 non-null   float16
#  17  cholesterol_100g         9053 non-null   float16
#  18  carbohydrates_100g       12862 non-null  float16
#  19  sugars_100g              12033 non-null  float16
#  20  fiber_100g               9338 non-null   float16
#  21  proteins_100g            12844 non-null  float16
#  22  salt_100g                12714 non-null  float16
#  23  sodium_100g              12714 non-null  float16
#  24  vitamin-a_100g           7963 non-null   float16
#  25  vitamin-c_100g           8114 non-null   float16
#  26  calcium_100g             8845 non-null   float16
#  27  iron_100g                8853 non-null   float16
#  28  nutrition-score-fr_100g  8301 non-null   float16
# dtypes: float16(16), float64(2), object(11)
# memory usage: 16.1 MB

# %% [markdown]
# ## Conclusion
# We should now be able to read the entire dataset by specifying the subset of columns that we are actually interested in, and providing a data type mapping for these columns.
